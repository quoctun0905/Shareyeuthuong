# %% [markdown]
# <h1>
# <font color="red">Day 3: Ngày quyết định thông minh.</font>
# </h1>
# <br/><br/><br/>
# <center>
# <img width="80%" height="400px" src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExZ21nZXZ0czI2cDI1NTJ2c3V5OWc0a3p1YXp6NXg3ZGsxcmZrNGY4OCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/3oipPTHYlTpCw8oBBy/giphy.gif" />
# </center>

# %% [markdown]
# ### 🌟 Bí Ẩn Của Khu Rừng Số Học
# Trong khu rừng này, có một con đường mòn dẫn đến hai ngôi làng bí ẩn: Làng Số Chẵn và Làng Số Lẻ. Để biết được con đường nào dẫn đến làng nào, chúng ta cần phải giải một bí ẩn: Làm sao để biết một số là số chẵn hay số lẻ?
#
# ### 🔍 Phép Thuật Chia Lấy Dư
# Chúng ta có một phép thuật trong túi: Toán tử chia lấy dư (%). Phép thuật này sẽ giúp chúng ta xác định một số bí mật, nằm ẩn sau mỗi con số.
#
# > Hãy thử nghiệm phép thuật này với số 4, một viên đá quý mà chúng ta tìm thấy trên con đường:

# %%
# Viên đá quý mà chúng ta tìm thấy là số 4
vien_da_quy = 4

# Sử dụng phép thuật chia lấy dư để khám phá bí mật
if vien_da_quy % 2 == 0:
  print("Hỡi kẻ phiêu lưu, con đường này dẫn đến Làng Số Chẵn.")
else:
  print("Cẩn thận! Con đường này đưa chúng ta đến Làng Số Lẻ.")
# Out:
# Hỡi kẻ phiêu lưu, con đường này dẫn đến Làng Số Chẵn.

# %% [markdown]
# <center>
# <img height="340px" width="100%" src="https://cdn.techinasia.com/wp-content/uploads/2022/08/1660571035_fi-to-take-vc-money-or-not.gif" />
# </center>

# %% [markdown]
# ### Câu Chuyện Về Cánh Cổng Bí Ẩn

# %%
# Mật khẩu mà chúng ta chọn
mat_khau = 12

# Điều kiện để qua cánh cổng
if mat_khau > 10:
  print("Cánh cổng mở ra, chào mừng bạn đến với khu vườn bí ẩn!")
else:
  print("Rất tiếc, cánh cổng không mở. Hãy thử mật khẩu khác.")
# Out:
# Cánh cổng mở ra, chào mừng bạn đến với khu vườn bí ẩn!

# %% [markdown]
# <h1>
# <font color="red">Hệ Thống Gợi Ý Hoạt Động Thư Giãn Buổi Tối
# </font>
# </h1>
#
# <p>
# Bài Toán: Tạo một hệ thống hoặc ứng dụng gợi ý hoạt động thư giãn cho buổi tối dựa trên điều kiện thời tiết và sở thích cá nhân.
# </p>

# %%
# Giả định rằng chúng ta đã có dữ liệu thời tiết và sở thích cá nhân của người dùng

# Dữ liệu mẫu
thoi_tiet_hien_tai = "mưa"  # Các tùy chọn có thể là "nắng", "mưa", "lạnh"
so_thich_ca_nhan = ["xem phim", "đi dạo", "đọc sách"]

# Hàm gợi ý hoạt động dựa trên thời tiết và sở thích
def goi_y_hoat_dong(thoi_tiet, so_thich):
    hoat_dong_goi_y = []

    if "xem phim" in so_thich and thoi_tiet == "mưa":
        hoat_dong_goi_y.append("xem phim tại nhà")

    if "đi dạo" in so_thich and thoi_tiet == "nắng":
        hoat_dong_goi_y.append("đi dạo trong công viên")

    if "đọc sách" in so_thich and (thoi_tiet == "nắng" or thoi_tiet == "mưa"):
        hoat_dong_goi_y.append("thư giãn với một cuốn sách")

    # Nếu không có hoạt động phù hợp, gợi ý một hoạt động thư giãn khác
    if not hoat_dong_goi_y:
        hoat_dong_goi_y.append("thử một sở thích mới tại nhà")

    return hoat_dong_goi_y

# Gọi hàm và in ra gợi ý
hoat_dong_duoc_goi_y = goi_y_hoat_dong(thoi_tiet_hien_tai, so_thich_ca_nhan)
print("Hoạt động gợi ý cho buổi tối của bạn:")
for hoat_dong in hoat_dong_duoc_goi_y:
    print("-", hoat_dong)
# Out:
# Hoạt động gợi ý cho buổi tối của bạn:
# - xem phim tại nhà
# - thư giãn với một cuốn sách

# %% [markdown]
# <center>
# <img height="350px" width="70%" src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExNXJiaDRwb3I2Z3ZoOXU1a3F2MDRrYjZuOWJpMzB0bG5ub3NwdHE2cyZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/hQXDWnh6tq9QCDtqYE/giphy.gif"/>
# </center>

# %%
# @title Phân loại tuổi tác. {run: "auto"}
age = 49 # @param {type:"slider", min:0, max:90, step:1}

if age < 13:
  print("Trẻ em")
elif age < 18:
  print("Thanh thiếu niên")
else:
  print("Người lớn")
# Out:
# Người lớn

# %% [markdown]
# > If-Else là công cụ linh hoạt cho phép bạn xây dựng logic phức tạp trong chương trình của mình một cách dễ dàng.

# %% [markdown]
# ### Phần 2: Tính điểm hòa vốn cho sản phẩm mới.
# \- Sau khi khám phá thế giới if-else, chúng ta sẽ dấn thân vào một cuộc phiêu lưu mới với một thách thức kinh tế thú vị: điểm hòa vốn. Hãy cùng nhau tìm hiểu xem điểm hòa vốn là gì và tại sao nó lại quan trọng trong việc ra quyết định cho các dự án kinh doanh nhé!
#
# \- Khi bắt đầu một dự án hay phát triển sản phẩm mới, việc tính toán điểm hòa vốn (break-even point) là một bước quan trọng giúp bạn xác định số lượng sản phẩm cần bán để bù đắp chi phí và bắt đầu sinh lời. Dưới đây là cách tiếp cận để tính điểm hòa vốn cho sản phẩm mới của bạn:
#
# <center>
# <img width="100%" height="300px" src="https://www.legalraasta.com/blog/wp-content/uploads/2019/04/bea-7.png"/>
# </center>
#
# * #### Bước 1: Xác Định Chi Phí Cố Định (Fixed Costs)
# Chi phí cố định là những chi phí không thay đổi dù số lượng sản phẩm sản xuất có thay đổi. Ví dụ: tiền thuê mặt bằng, lương nhân viên, chi phí quảng cáo.
#
# * #### Bước 2: Xác Định Giá Bán Sản Phẩm và Chi Phí Biến Đổi (Variable Costs)
# Giá Bán Sản Phẩm: Đây là giá mà bạn dự định bán sản phẩm cho khách hàng.
# Chi Phí Biến Đổi: Chi phí này thay đổi dựa trên số lượng sản phẩm sản xuất. Ví dụ: nguyên liệu, tiền công trực tiếp.
#
# * #### Bước 3: Tính Đóng Góp Biên Lợi Nhuận (Contribution Margin)
# Đóng góp biên lợi nhuận được tính bằng cách trừ chi phí biến đổi khỏi giá bán sản phẩm.
#
#   > **Công thức:** Đóng Góp Biên Lợi Nhuận = Giá Bán Sản Phẩm – Chi Phí Biến Đổi
#
# * #### Bước 4: Tính Điểm Hòa Vốn (Break-Even Point)
# Cuối cùng, bạn sẽ tính điểm hòa vốn bằng cách chia chi phí cố định cho đóng góp biên lợi nhuận.
#
#   > **Công thức:** Điểm Hòa Vốn = Chi Phí Cố Định / Đóng Góp Biên Lợi Nhuận
# <br/><br/>
#
# #### Ví Dụ Minh Họa
# Giả sử chi phí cố định cho sản phẩm mới là 100,000 USD, giá bán dự kiến là 50 USD/sản phẩm, và chi phí biến đổi là 20 USD/sản phẩm.
#
# Đóng Góp Biên Lợi Nhuận: 50 − 20 = 30
# 50 − 20 = 30 USD/sản phẩm
# Điểm Hòa Vốn: 100,000 ÷ 30 = 3333.33
# 100,000 ÷ 30 = 3333.33 sản phẩm
# Vậy bạn cần bán ít nhất khoảng 3334 sản phẩm để hòa vốn.
#
# <br/>
# <br/>
#
# #### Để tính điểm hòa vốn sử dụng if-else, chúng ta có thể thêm một số logic vào mã lệnh để xử lý các trường hợp khác nhau, chẳng hạn như khi đóng góp biên lợi nhuận bằng 0 (tránh chia cho 0) hoặc khi chi phí cố định bằng 0 (sản phẩm không cần bán bất kỳ đơn vị nào để hòa vốn). Dưới đây là ví dụ:

# %%
# Định nghĩa các biến theo ví dụ minh họa
chi_phi_co_dinh = 100000  # USD
gia_ban_san_pham = 50  # USD/sản phẩm
chi_phi_bien_doi = 20  # USD/sản phẩm

# Tính Đóng Góp Biên Lợi Nhuận
dong_gop_bien_loi_nhuận = gia_ban_san_pham - chi_phi_bien_doi

# Sử dụng if-else để xử lý các trường hợp đặc biệt
if dong_gop_bien_loi_nhuận <= 0:
    print("Lỗi: Đóng góp biên lợi nhuận không hợp lệ (<=0). Không thể tính điểm hòa vốn.")
elif chi_phi_co_dinh <= 0:
    print("Lưu ý: Không có chi phí cố định. Sản phẩm không cần bán bất kỳ đơn vị nào để hòa vốn.")
else:
    # Tính Điểm Hòa Vốn
    diem_hoa_von = chi_phi_co_dinh / dong_gop_bien_loi_nhuận
    print("Đóng Góp Biên Lợi Nhuận:", dong_gop_bien_loi_nhuận, "USD/sản phẩm")
    print("Điểm Hòa Vốn:", round(diem_hoa_von), "sản phẩm")
# Out:
# Đóng Góp Biên Lợi Nhuận: 30 USD/sản phẩm
# Điểm Hòa Vốn: 3333 sản phẩm

# %%
# @title Hãy thử tính điểm hòa vốn khác nhau bằng cách thay đổi thông số các giá trị tại đây: {run: "auto"}
chi_phi_co_dinh = 10000 # @param {type:"integer"}
gia_ban_san_pham = 500 # @param {type:"integer"}
chi_phi_bien_doi = 20 # @param {type:"integer"}

# Tính Đóng Góp Biên Lợi Nhuận
dong_gop_bien_loi_nhuận = gia_ban_san_pham - chi_phi_bien_doi

# Sử dụng if-else để xử lý các trường hợp đặc biệt
if dong_gop_bien_loi_nhuận <= 0:
    print("Lỗi: Đóng góp biên lợi nhuận không hợp lệ (<=0). Không thể tính điểm hòa vốn.")
elif chi_phi_co_dinh <= 0:
    print("Lưu ý: Không có chi phí cố định. Sản phẩm không cần bán bất kỳ đơn vị nào để hòa vốn.")
else:
    # Tính Điểm Hòa Vốn
    diem_hoa_von = chi_phi_co_dinh / dong_gop_bien_loi_nhuận
    print("Đóng Góp Biên Lợi Nhuận:", dong_gop_bien_loi_nhuận, "USD/sản phẩm")
    print("Điểm Hòa Vốn:", round(diem_hoa_von), "sản phẩm")
# Out:
# Đóng Góp Biên Lợi Nhuận: 480 USD/sản phẩm
# Điểm Hòa Vốn: 21 sản phẩm

# %% [markdown]
# #### Chúng mình đã cùng đi qua if-else và cách sử dụng if-else sao cho hiệu quả và ứng dụng, trong hành trình học tập này, mình thấy một số điểm cần lưu ý của if-else:
#
# 📝 Note Nhanh: Lưu Ý Khi Dùng If-Else trong Python
#
# 🎯 Điều Kiện Phải Rõ Ràng: Đảm bảo rằng mỗi if đều dựa trên một điều kiện cụ thể và không gây nhầm lẫn.
#
# 🛠 Cẩn Thận với Indentation: Python yêu cầu thụt đầu dòng chính xác. Sai sót ở đây sẽ dễ dẫn đến IndentationError.
#
# ✅ Chọn Toán Tử Đúng: Phân biệt rõ == dùng để so sánh và = dùng để gán giá trị.
#
# 🚫 Tránh So Sánh Trực Tiếp với Boolean: Thay vì if condition == True:, hãy sử dụng if condition:.
#
# 🤹♂️ Giảm Bớt If-Else Lồng Nhau: Đừng để code trở nên rối beng với quá nhiều if-else lồng nhau. Sử dụng elif hoặc chia nhỏ thành hàm.
#
# 🧐 Cẩn Thận với None: Kiểm tra giá trị None bằng is None hoặc is not None.
#
# 🔍 Dùng Ternary Operators Cho Đơn Giản: Cho phép viết if-else ngắn gọn: x = 5 if condition else 0.
#
# 📊 Kiểm Tra Hiệu Quả
#
# <center>
# <img height="400px" width="80%" src="https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExMnZnanh5cmVuM2NvdW1ocGF5eWN0eHV6dW1ucnh2YmtpcnAyemJ0dyZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/l3q2FnW3yZRJVZH2g/giphy.gif" />
# </center>
